# %% [markdown]
# <a href="https://colab.research.google.com/github/PahlavaniWorkshop/AIWorkshop/blob/main/linear_regression_krupa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression
# ## Linear regression models the relationship between dependent (y) and independent (x) variables through a straight line or plane. It assumes a linear relationship and aims to minimize the squared differences between observed and predicted values. Widely used for prediction and understanding in various fields like economics, finance, and sciences.
#
# ## Dataset link - https://www.kaggle.com/datasets/krupadharamshi/fuelconsumption

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. Data Collection
# ## Importing libraries and reading datasets

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/content/drive/MyDrive/Dataset/FuelConsumptionCo2.csv")
df
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# ...

# %%
data = df[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]

# %%
data
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0            2.0          4                   8.5           196
# 1            2.4          4                   9.6           221
# 2            1.5          4                   5.9           136
# 3            3.5          6                  11.1           255
# 4            3.5          6                  10.6           244
# ...          ...        ...                   ...           ...
# 1062         3.0          6                  11.8           271
# 1063         3.2          6                  11.5           264
# 1064         3.0          6                  11.8           271
# 1065         3.2          6                  11.3           260
# 1066         3.2          6                  12.8           294
#
# [1067 rows x 4 columns]

# %%
data.duplicated().value_counts()
# Out:
# False    558
# True     509
# Name: count, dtype: int64

# %%
X = data.drop("CO2EMISSIONS", axis=1)
y = data["CO2EMISSIONS"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X ,y , random_state=11 , test_size=0.2 , shuffle=True)

# %%
model = LinearRegression()

# %%
model.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB
# 315         2.4          4                   8.6
# 634         5.2         10                  15.7
# 148         2.4          4                   8.2
# 437         5.3          8                  16.5
# 396         1.6          4                   8.0
# ..          ...        ...                   ...
# 187         3.6          6                  12.6
# 79          2.0          4                   6.7
# 31          4.0          8                  11.3
# 776         5.5          8                  10.7
# 277         3.6          6                  10.5
#
# [214 rows x 3 columns]

# %%
pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-699c0549c49f> in <cell line: 1>()
# ----> 1 pred = model.predict(X_test)
#       2
#       3
#       4
#       5
#
# NameError: name 'model' is not defined

# %%
from sklearn.metrics import f1_score , mean_absolute_error , r2_score , mean_squared_error

# %%
mean_absolute_error(y_test , pred)
# Out:
# 15.631450016951158

# %%
mean_squared_error(y_test , pred)
# Out:
# 486.7858161992379

# %%
np.sqrt(mean_squared_error(y_test , pred))
# Out:
# 22.06322315980233

# %% [markdown]
# # 2. Exploratory Data Analysis
# ## In EDA we perform task like cleaning, describing and modifying the data accordingly

# %%
fc = df

# %%
fc.head(10)  #Shows the 1st 5 rows of the data
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
# 5       2014  ACURA         RLX     MID-SIZE         3.5          6
# 6       2014  ACURA          TL     MID-SIZE         3.5          6
# 7       2014  ACURA      TL AWD     MID-SIZE         3.7          6
# 8       2014  ACURA      TL AWD     MID-SIZE         3.7          6
# 9       2014  ACURA         TSX      COMPACT         2.4          4
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# ...

# %%
fc.shape #dimension of the data
# Out:
# (1067, 13)

# %%
fc.info()  #info about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# ...

# %%
fc.describe()  #stats of the data
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %%
fc.columns   #reading the columns
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %% [markdown]
# # 3. Data Visualization
# ## Data visualization involves presenting data in graphical or pictorial formats, aiding in understanding patterns and relationships within the data.

# %%
visual = fc[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB_MPG','CO2EMISSIONS']]
visual.hist()
plt.show()

#visualizing the data in histogram

# %%
cfc = fc

# %%
for i in cfc[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_HWY','CO2EMISSIONS']]:
    plt.scatter(cfc[i],cfc['CO2EMISSIONS'],color = 'green')
    plt.xlabel(i)
    plt.ylabel("EMISSION")
    plt.show()
#visualizing the data in scatter plot

# %% [markdown]
# # 4.Model Training
# ## In model training we split the data in train(80%), test(20%) and train the model.

# %%
mask = np.random.rand(len(cfc))<0.80
train = cfc[mask]
test = cfc[~mask]
# diving dataset into training (80%) and testin(20%)

# %%
#Apply Linear Regression on Training data
#calculating coefficient and intercept
coefficient=[]
intercept=[]
regress_model = {}
for i in ['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_HWY']:
    reg = linear_model.LinearRegression()
    train_x = np.asanyarray(train[[i]])
    train_y = np.asanyarray(train[['FUELCONSUMPTION_HWY']])
    reg.fit(train_x, train_y)
    regress_model[i] = reg
    print("Relation between {} & {}".format(i, "'FUELCONSUMPTION_HWY'"))
    print("Coefficient :", reg.coef_)
    print("Intercept :", reg.intercept_)
    coefficient.append(reg.coef_)
    intercept.append(reg.intercept_)
    print('\n')
# Out:
# Relation between ENGINESIZE & 'FUELCONSUMPTION_HWY'
# Coefficient : [[1.56023554]]
# Intercept : [4.25427021]
#
#
# Relation between CYLINDERS & 'FUELCONSUMPTION_HWY'
# Coefficient : [[1.17234955]]
# Intercept : [2.70282093]
#
#
# Relation between FUELCONSUMPTION_HWY & 'FUELCONSUMPTION_HWY'
# Coefficient : [[1.]]
# Intercept : [-3.55271368e-15]

# %%
#Use regression parameter to model linear equation
j=0
for i in train[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_HWY']]:
    plt.scatter(train[i], train['FUELCONSUMPTION_HWY'],  color='blue')
    x=train[i].values
    print(x.shape)
    y=coefficient[j][0]*x + intercept[j]
    print(y.shape)
    l=len(y)
    y=np.reshape(y,(l,))
    plt.plot(x, y, '-r')
    plt.xlabel(i)
    plt.ylabel("Emission")
    plt.show()
    j=j+1
# Out:
# (824,)
# (824,)
# (824,)
# (824,)
# (824,)
# (824,)

# %% [markdown]
# # 5.Model performance
# ## The effectiveness of a predictive model in accurately capturing patterns and making reliable predictions on unseen data.

# %%
#Evaluate model performance on test data
#calculating Mean absolute error,Residual sum of squares,R2-score
from sklearn.metrics import r2_score
for i in train[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_HWY']]:
    test_x = np.asanyarray(test[[i]])
    test_y = np.asanyarray(test[['FUELCONSUMPTION_HWY']])
    test_y_ = regress_model[i].predict(test_x)
    print("Fitting Error between {} & {}".format(i,"'FUELCONSUMPTION_HWY'"))
    print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_ - test_y)))
    print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_ - test_y) ** 2))
    print("R2-score: %.2f" % r2_score(test_y_ , test_y) )
    print('\n')
# Out:
# Fitting Error between ENGINESIZE & 'FUELCONSUMPTION_HWY'
# Mean absolute error: 1.21
# Residual sum of squares (MSE): 2.85
# R2-score: 0.45
#
#
# Fitting Error between CYLINDERS & 'FUELCONSUMPTION_HWY'
# Mean absolute error: 1.39
# Residual sum of squares (MSE): 3.70
# R2-score: 0.29
#
#
# Fitting Error between FUELCONSUMPTION_HWY & 'FUELCONSUMPTION_HWY'
# Mean absolute error: 0.00
# Residual sum of squares (MSE): 0.00
# R2-score: 1.00
